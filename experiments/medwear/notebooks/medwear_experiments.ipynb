# %% [markdown]
# # MedWear Wearable Analytics — ML Experiments
#
# 1. `npm run export:features`
# 2. Load `experiments/data/medwear/features_v1.csv`
# 3. Train via `experiments/medwear/train.py`

# %%
import pandas as pd
df = pd.read_csv('../../data/medwear/features_v1.csv')
df.describe()
